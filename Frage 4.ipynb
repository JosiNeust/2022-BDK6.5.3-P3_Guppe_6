# %% [markdown]
# # Frage 4: In welchem der letzten 10 Jahre hat Tim Burton bei den meisten Filmen Regie geführt?

# %%
import urllib.request
import gzip
import pandas as pd
import matplotlib.pyplot as plt

# %%
url_data_crew = "https://datasets.imdbws.com/title.crew.tsv.gz"
url_data_year = "https://datasets.imdbws.com/title.basics.tsv.gz"

# %%
title_crew_file = "title_crew_file.csv", url_data_crew
title_year_file = "title_year_file.csv", url_data_year

# %%
urllib.request.urlretrieve(title_crew_file[1], title_crew_file[0])
urllib.request.urlretrieve(title_year_file[1], title_year_file[0])
# Out:
# ('title_year_file.csv', <http.client.HTTPMessage at 0x1b11f93a550>)

# %%
crew = pd.read_csv(title_crew_file[0], compression = 'gzip', sep = "\t")
year = pd.read_csv(title_year_file[0], compression = 'gzip', sep = "\t")
# Out:
# C:\Users\neust\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
crew
# Out:
#             tconst            directors                        writers
# 0        tt0000001            nm0005690                             \N
# 1        tt0000002            nm0721526                             \N
# 2        tt0000003            nm0721526                             \N
# 3        tt0000004            nm0721526                             \N
# 4        tt0000005            nm0005690                             \N
# ...            ...                  ...                            ...
# 8992161  tt9916848  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 8992162  tt9916850  nm5519375,nm5519454  nm6182221,nm1628284,nm2921377
# 8992163  tt9916852  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 8992164  tt9916856           nm10538645                      nm6951431
# 8992165  tt9916880            nm0996406            nm1482639,nm2586970
#
# [8992166 rows x 3 columns]

# %%
directorname = crew[crew["directors"] == "nm0000318"]
#director = directorname.tconst
#director

# %%
print(directorname)
# Out:
#              tconst  directors  \
# 83029     tt0084868  nm0000318
# 85387     tt0087291  nm0000318
# 87826     tt0089791  nm0000318
# 92637     tt0094721  nm0000318
# 94760     tt0096895  nm0000318
# 97286     tt0099487  nm0000318
# 101480    tt0103776  nm0000318
# 107245    tt0109707  nm0000318
# 114313    tt0116996  nm0000318
# 122304    tt0125603  nm0000318
# 129464    tt0133152  nm0000318
# 157425    tt0162661  nm0000318
# 239072    tt0249567  nm0000318
# 282390    tt0294940  nm0000318
# 296457    tt0309721  nm0000318
# 305460    tt0319061  nm0000318
# 352290    tt0367594  nm0000318
# 383631    tt0400231  nm0000318
# 391423    tt0408236  nm0000318
# 488485    tt0508431  nm0000318
# 1049946   tt1014759  nm0000318
# 1398794   tt1077368  nm0000318
# 1673995   tt1126590  nm0000318
# 1764656   tt1142977  nm0000318
# 2861108  tt13443470  nm0000318
# 3208866  tt14077386  nm0000318
# 3208871  tt14077394  nm0000318
# 3208872  tt14077396  nm0000318
# 3208875  tt14077400  nm0000318
# ...

# %%
year
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 8992161  tt9916848  tvEpisode              Episode #3.17
# 8992162  tt9916850  tvEpisode              Episode #3.19
# 8992163  tt9916852  tvEpisode              Episode #3.20
# 8992164  tt9916856      short                   The Wind
# 8992165  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita       0      1894      \N              1
# 1           Le clown et ses chiens       0      1892      \N              5
# ...

# %%
#directorname = crew[crew["directors"] == "nm0000318"]
year["tconst"] = "tt0084868"

# %%
year["endYear"].min()
# Out:
# '1906'

# %%
year["startYear"].max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of 0          1894
# 1          1892
# 2          1892
# 3          1892
# 4          1893
#            ...
# 8992161    2010
# 8992162    2010
# 8992163    2010
# 8992164    2015
# 8992165    2014
# Name: startYear, Length: 8992166, dtype: object>
